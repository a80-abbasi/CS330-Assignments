# %%
# !git clone "https://github.com/a80-abbasi/CS330-Assignments"
# Out:
# Cloning into 'CS330-Assignments'...
# remote: Enumerating objects: 25, done.
# remote: Counting objects: 100% (25/25), done.
# remote: Compressing objects: 100% (18/18), done.
# remote: Total 25 (delta 5), reused 22 (delta 5), pack-reused 0
# Unpacking objects: 100% (25/25), done.

# %%
# %cd CS330-Assignments/HW0
# Out:
# /content/CS330-Assignments/HW0

# %%
# !ls
# Out:
# dataset.py     losses.py  models.py	requirements.txt
# evaluation.py  main.py	  multitask.py	utils.py

# %%
# !python main.py --factorization_weight 0.99 --regression_weight 0.01 --logdir run/shared=True LF=0.99 LR=0.01
# Out:
# Namespace(epochs=200, factorization_weight=0.99, logdir='run/shared=True', regression_weight=0.01, shared_embeddings=True, test_fraction=0.05)
# epoch=0
# Factorization Loss=0.4634724329075506, score_loss=3.5054427080897876, joint_loss=0.49389213868366777
# mrr=0.04935891052046185, mse=0.9308232665061951
# --------------------------------------------------
# epoch=1
# Factorization Loss=0.3085983067110021, score_loss=0.8989244508807377, joint_loss=0.3145015716392507
# mrr=0.055520539794316245, mse=0.8850207328796387
# --------------------------------------------------
# epoch=2
# Factorization Loss=0.23502654325897976, score_loss=0.8742071609663707, joint_loss=0.24141835140925583
# mrr=0.06287772413322415, mse=0.8794465065002441
# --------------------------------------------------
# epoch=3
# Factorization Loss=0.21494156146241772, score_loss=0.8659543007291773, joint_loss=0.22145169136184517
# mrr=0.06329471996203599, mse=0.8798165917396545
# ...

# %%
# !python main.py --factorization_weight 0.5 --regression_weight 0.5 --logdir run/shared=True LF=0.5 LR=0.5
# Out:
# Namespace(epochs=200, factorization_weight=0.5, logdir='run/shared=True', regression_weight=0.5, shared_embeddings=True, test_fraction=0.05)
# epoch=0
# Factorization Loss=0.4823214412536672, score_loss=3.3431377814662073, joint_loss=1.9127296061925991
# mrr=0.05172389032253733, mse=0.8998619318008423
# --------------------------------------------------
# epoch=1
# Factorization Loss=0.44709690588135875, score_loss=0.8974742516074129, joint_loss=0.6722855790648409
# mrr=0.05351653973115361, mse=0.8854919075965881
# --------------------------------------------------
# epoch=2
# Factorization Loss=0.4166693705063994, score_loss=0.8850102631315109, joint_loss=0.650839816178045
# mrr=0.053163188282381195, mse=0.8824864029884338
# --------------------------------------------------
# epoch=3
# Factorization Loss=0.3890923254432217, score_loss=0.8814598578278736, joint_loss=0.6352760905540118
# mrr=0.052295415419928055, mse=0.8846264481544495
# ...

# %%
# !python main.py --no_shared_embeddings --factorization_weight 0.5 --regression_weight 0.5 --logdir run/shared=False LF=0.5 LR=0.5
# Out:
# Namespace(epochs=200, factorization_weight=0.5, logdir='run/shared=False', regression_weight=0.5, shared_embeddings=False, test_fraction=0.05)
# epoch=0
# Factorization Loss=0.4820795996535209, score_loss=2.8907738010729513, joint_loss=1.6864266973990265
# mrr=0.056464302662213424, mse=0.8900976777076721
# --------------------------------------------------
# epoch=1
# Factorization Loss=0.3482571907181253, score_loss=0.8955388158880254, joint_loss=0.6218980018810559
# mrr=0.061030410361117816, mse=0.877174437046051
# --------------------------------------------------
# epoch=2
# Factorization Loss=0.23739485374541694, score_loss=0.8856392783182924, joint_loss=0.5615170647700628
# mrr=0.06642386947867035, mse=0.8680802583694458
# --------------------------------------------------
# epoch=3
# Factorization Loss=0.21299438318738373, score_loss=0.8787502473400485, joint_loss=0.545872314803062
# mrr=0.07085103330496019, mse=0.8708167672157288
# ...
